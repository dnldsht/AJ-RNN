# %% [markdown]
# labels.npy corrisponde alla struttura che contiene le info di classe, oggetto e posizione sulla griglia. Nel caso del codice che ho su github,
#
#  0 = row_id, 1 = col_id, 2 = class_id, colonna 3 = object_id

# %%
import json 
import time
start_train_time = time.time()

history = {
  "accuracy": [
    0.356391578912735,
    0.5286837816238403,
    0.5433985590934753,
    0.5457878112792969,
    0.5431330800056458,
    0.5474944114685059,
    0.5533095598220825,
    0.5592890381813049,
    0.5643582940101624,
    0.5690483450889587,
    0.5734602808952332,
    0.5813359618186951,
    0.5924353003501892,
    0.6013855338096619
  ],
  "c_loss": [
    1.979874849319458,
    1.6143522262573242,
    1.4882665872573853,
    1.417303442955017,
    1.3690769672393799,
    1.3320837020874023,
    1.301613450050354,
    1.275427222251892,
    1.2523049116134644,
    1.231506109237671,
    1.2125455141067505,
    1.1950864791870117,
    1.1788854598999023,
    1.163761019706726
  ],
  "d_loss": [
    0.5037544965744019,
    0.49955862760543823,
    0.49562394618988037,
    0.4943494498729706,
    0.49431997537612915,
    0.4944867789745331,
    0.49438872933387756,
    0.4943990409374237,
    0.49448949098587036,
    0.4944833219051361,
    0.4943176507949829,
    0.4943164587020874,
    0.49429330229759216,
    0.4942574203014374
  ],
  "g_loss": [
    0.20927143096923828,
    0.20829540491104126,
    0.21383622288703918,
    0.21628537774085999,
    0.2163069099187851,
    0.21605832874774933,
    0.21569150686264038,
    0.2157120257616043,
    0.21549592912197113,
    0.2153633087873459,
    0.21549195051193237,
    0.21549274027347565,
    0.21551358699798584,
    0.2156859189271927
  ],
  "imp_loss": [
    0.0001894737797556445,
    0.00018811975314747542,
    0.00018668832490220666,
    0.00018524841289035976,
    0.00018381612608209252,
    0.0001823952334234491,
    0.0001809867681004107,
    0.00017959068645723164,
    0.00017820679931901395,
    0.00017683506303001195,
    0.00017547527386341244,
    0.0001741271116770804,
    0.00017279053281527013,
    0.00017146555182989687
  ],
  "reg_loss": [
    0.007147565018385649,
    0.007120877038687468,
    0.007094032131135464,
    0.00706721656024456,
    0.007040465250611305,
    0.007013789378106594,
    0.006987190339714289,
    0.006960666738450527,
    0.006934222299605608,
    0.006907852832227945,
    0.006881562061607838,
    0.006855348125100136,
    0.006829210091382265,
    0.006803149823099375
  ],
  "total_g_loss": [
    0.216608464717865,
    0.21560439467430115,
    0.2211170196533203,
    0.22353777289390564,
    0.2235310673713684,
    0.22325460612773895,
    0.22285957634449005,
    0.2228522151708603,
    0.22260841727256775,
    0.22244803607463837,
    0.22254906594753265,
    0.22252219915390015,
    0.22251556813716888,
    0.22266049683094025
  ],
  "val_accuracy": [
    0.5235164165496826,
    0.5271464586257935,
    0.6157276034355164,
    0.6946417093276978,
    0.6788983345031738,
    0.6738478541374207,
    0.6743213534355164,
    0.6769254803657532,
    0.680200457572937,
    0.6830018758773804,
    0.6855666041374207,
    0.6875394582748413,
    0.6900647282600403,
    0.6940498948097229
  ]
}

train_time = round(time.time()-start_train_time, 2)

# %%
{
  'train_accuracy': history['accuracy'][-1],
  'val_accuracy': max(history['val_accuracy']),
  'best_val_epoch': max(history['val_accuracy']),
  'best_val_epoch': history['val_accuracy'].index(max(history['val_accuracy'])),
  'train_time': train_time
}
# Out:
# {'train_accuracy': 0.6013855338096619,
#  'val_accuracy': 0.6946417093276978,
#  'best_val_epoch': 3,
#  'train_time': 0.0}

# %%
list(enumerate(history.keys())), history.values()
# Out:
# ([(0, 'accuracy'),
#   (1, 'c_loss'),
#   (2, 'd_loss'),
#   (3, 'g_loss'),
#   (4, 'imp_loss'),
#   (5, 'reg_loss'),
#   (6, 'total_g_loss'),
#   (7, 'val_accuracy')],
# ...
